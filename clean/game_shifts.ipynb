# %%
import pandas as pd

# %%
#understand the dataset

df_game_shifts = pd.read_csv(r"C:\Users\zacle\Desktop\Serene\Project\NHL\ETL\extract\raw_data\game_shifts.csv")
df_game_shifts.head(5)
df_game_shifts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11882735 entries, 0 to 11882734
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   game_id      int64
#  1   player_id    int64
#  2   period       int64
#  3   shift_start  int64
#  4   shift_end    float64
# dtypes: float64(1), int64(4)
# memory usage: 453.3 MB

# %%
# Create a new dataframe from df_game_plays_players (copying original to preserve data)
df_clean_game_shifts = df_game_shifts.copy()

# %%
df_clean_game_shifts.head(10)
# Out:
#       game_id  player_id  period  shift_start  shift_end
# 0  2018020001    8466139       1            0       42.0
# 1  2018020001    8466139       1          207      247.0
# 2  2018020001    8466139       1          375      413.0
# 3  2018020001    8466139       1          556      574.0
# 4  2018020001    8466139       1          605      631.0
# 5  2018020001    8466139       1          662      703.0
# 6  2018020001    8466139       1          869      883.0
# 7  2018020001    8466139       1          941      968.0
# 8  2018020001    8466139       1         1146     1200.0
# 9  2018020001    8466139       2         1200     1219.0

# %%
# Change data type syntax - df['column_name'] = df['column_name'].astype('desired_data_type')
df_clean_game_shifts['game_id'] = df_clean_game_shifts['game_id'].astype(str)
df_clean_game_shifts['player_id'] = df_clean_game_shifts['player_id'].astype(str)

# %%
# Null - All - check for missing or null values entire dataset
# Results : No null values

df_clean_game_shifts.isnull().sum()
# Out:
# game_id           0
# player_id         0
# period            0
# shift_start       0
# shift_end      2258
# dtype: int64

# %%
#save file locally
df_clean_game_shifts.to_csv(r"C:\Users\zacle\Desktop\Serene\Project\NHL\ETL\clean\game_shifts.csv", index=False)
